# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %%
(x_train_data, t_train_data), (x_test_data, t_test_data) = mnist.load_data()

# %%
print(x_train_data.shape, t_train_data.shape)
print(x_test_data.shape, t_test_data.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
img = x_train_data[10000][1:] #굳이 reshape안해도 된다.(이미 되어있어서)
                              #1열:정답, 2열~785열: 숫자 이미지(각각에는 0~255까지 값이 존재)
plt.imshow(img, cmap = 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
img1 = x_train_data[21000][1:]

plt.imshow(img1)
plt.show
# Out:
# <function matplotlib.pyplot.show>
