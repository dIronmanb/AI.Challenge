# %%
from keras.models import Sequential
from keras.layers import Dense
from google.colab import files

  print("User uploaded file \"{name}\" with length {length} bytes"\
        .format(name = fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-46a892b5-db96-452c-a02c-d05b459ceb94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46a892b5-db96-452c-a02c-d05b459ceb94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ThoraricSurgery.csv to ThoraricSurgery.csv
# User uploaded file "ThoraricSurgery.csv" with length 21727 bytes

# %%
import numpy as np
import tensorflow as tf

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed) #책에서는 tf.set_random_seed(seed)

# %%
Data_set = np.loadtxt("ThoraricSurgery.csv", delimiter = ',')

# %%
x = Data_set[:, 0:17]
t = Data_set[:, 17]

# %%
model = Sequential()
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
model.fit(x,t,epochs = 30, batch_size = 10)
# Out:
# Epoch 1/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.5702
# Epoch 2/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 3/30
# 47/47 [==============================] - 0s 973us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 4/30
# 47/47 [==============================] - 0s 888us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 5/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 6/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 7/30
# 47/47 [==============================] - 0s 956us/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 8/30
# 47/47 [==============================] - 0s 900us/step - loss: 0.1485 - accuracy: 0.8511
# Epoch 9/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1482 - accuracy: 0.8511
# Epoch 10/30
# 47/47 [==============================] - 0s 956us/step - loss: 0.1471 - accuracy: 0.8511
# Epoch 11/30
# 47/47 [==============================] - 0s 972us/step - loss: 0.1480 - accuracy: 0.8511
# Epoch 12/30
# 47/47 [==============================] - 0s 977us/step - loss: 0.1470 - accuracy: 0.8511
# Epoch 13/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1476 - accuracy: 0.8511
# Epoch 14/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1464 - accuracy: 0.8489
# Epoch 15/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.8511
# Epoch 16/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1470 - accuracy: 0.8489
# Epoch 17/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.8532
# Epoch 18/30
# 47/47 [==============================] - 0s 970us/step - loss: 0.1449 - accuracy: 0.8511
# Epoch 19/30
# 47/47 [==============================] - 0s 974us/step - loss: 0.1457 - accuracy: 0.8489
# Epoch 20/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1453 - accuracy: 0.8511
# Epoch 21/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.8532
# Epoch 22/30
# 47/47 [==============================] - 0s 997us/step - loss: 0.1441 - accuracy: 0.8532
# Epoch 23/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1454 - accuracy: 0.8532
# Epoch 24/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.8511
# Epoch 25/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 0.8489
# Epoch 26/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1451 - accuracy: 0.8532
# Epoch 27/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.8553
# Epoch 28/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1423 - accuracy: 0.8532
# Epoch 29/30
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.8532
# Epoch 30/30
# 47/47 [==============================] - 0s 958us/step - loss: 0.1470 - accuracy: 0.8511

# %%
print("\n Accuracy: %.4f" %(model.evaluate(x,t)[1]))
# Out:
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.8511
#
#  Accuracy: 0.8511

# %%
import matplotlib.pyplot as plt

# -*- coding: utf-8 -*-
import numpy as np

# x 값과 y값
x=[2, 4, 6, 8]
y=[81, 93, 91, 97]

# x와 y의 평균값
mx = np.mean(x)
my = np.mean(y)

# 기울기 공식의 분모
divisor = sum([(mx - i)**2 for i in x])

# 기울기 공식의 분자
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

print("분모:", divisor)
print("분자:", dividend)

# 기울기와 y 절편 구하기
a = dividend / divisor
b = my - (mx*a)

#original data
result_x = x
result_y = y
plt.scatter(result_x, result_y, c='r')

#new_point
new_x = np.array([2,4,6,8])
new_y = a*new_x + b
plt.scatter(new_x, new_y, c='b')

#new_line
x = np.arange(2,9)
y = a*x + b
plt.plot(x, y, color = 'y' )

#show graph
plt.show()
# Out:
# 분모: 20.0
# 분자: 46.0
